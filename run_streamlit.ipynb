# %% [markdown]
# # 🚀 Runner Streamlit: Uji Coba Model Hybrid Hate Speech
#
# Notebook ini digunakan untuk menginstal dependensi Streamlit dan meluncurkan aplikasi web pengujian interaktif untuk model **Hybrid BiLSTM & Logika Fuzzy**.

# %% [markdown]
# ### 1. Install Streamlit
# Jalankan cell di bawah ini untuk memastikan dependensi `streamlit` terinstal dalam environment virtual Anda.

# %%
# Install Streamlit
# !pip install streamlit
# Out:
# ...
#   Using cached streamlit-1.58.0-py3-none-any.whl.metadata (9.6 kB)
# ...
#   Using cached altair-6.2.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached cachetools-7.1.4-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached pyarrow-24.0.0-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# ...
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached starlette-1.3.1-py3-none-any.whl.metadata (6.4 kB)
# ...
#   Using cached uvicorn-0.49.0-py3-none-any.whl.metadata (6.7 kB)
# ...
#   Using cached httptools-0.8.0-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# ...
#   Using cached python_multipart-0.0.32-py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached websockets-16.0-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# ...

# %% [markdown]
# ### 2. Jalankan Aplikasi Web Streamlit
# Jalankan cell di bawah ini untuk meluncurkan server lokal Streamlit. Server akan berjalan secara background, dan browser web Anda akan otomatis terbuka menuju alamat localhost aplikasi.

# %%
# Jalankan server Streamlit
# !streamlit run app.py
# Out:
# ^C
